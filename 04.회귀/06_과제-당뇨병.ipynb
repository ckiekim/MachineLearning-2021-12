# %% [markdown]
# # 과제 - 당뇨병 데이터로 다중 회귀

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target
df.head(3)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0

# %% [markdown]
# - 각 피쳐별 산점도와 선형회귀선

# %%
_, axs = plt.subplots(nrows=2, ncols=5, figsize=(16,8))
for i, feature in enumerate(df.columns[:-1]):
    row, col = i//5, i%5
    sns.regplot(x=feature, y='target', data=df, ax=axs[row][col])

# %% [markdown]
# - 각 피쳐별 R squared value

# %%
from sklearn.linear_model import LinearRegression

# %%
y = diabetes.target
for feature in df.columns[:-1]:
    X = df[feature].values.reshape(-1,1)
    lr = LinearRegression()
    lr.fit(X, y)
    r2 = lr.score(X, y)
    print(f'{feature}: {r2:.4f}')
# Out:
# age: 0.0353
# sex: 0.0019
# bmi: 0.3439
# bp: 0.1949
# s1: 0.0450
# s2: 0.0303
# s3: 0.1559
# s4: 0.1853
# s5: 0.3202
# s6: 0.1463

# %% [markdown]
# - dataset 분리

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    diabetes.data, diabetes.target, test_size=0.1, random_state=2021
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((397, 10), (45, 10), (397,), (45,))

# %% [markdown]
# ### Regressor 별 MSE 비교

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
pred_lr = lr.predict(X_test)
mse_lr = mean_squared_error(y_test, pred_lr)

# %%
# SVR
svr = SVR()
svr.fit(X_train, y_train)
pred_sv = svr.predict(X_test)
mse_sv = mean_squared_error(y_test, pred_sv)

# %%
# Random Forest Regressor
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
pred_rf = rfr.predict(X_test)
mse_rf = mean_squared_error(y_test, pred_rf)

# %% [markdown]
# - 결과 비교

# %%
# MSE
print(f'LR: {mse_lr:.4f}, SVR: {mse_sv:.4f}, RFR: {mse_rf:.4f}')
# Out:
# LR: 2370.1979, SVR: 3960.9367, RFR: 3757.7289

# %%
# 실제값과 예측값 비교
df = pd.DataFrame({
    'y_test':y_test, 'LR':pred_lr, 'SVR':pred_sv, 'RFR':pred_rf
})
df.head(10)
# Out:
#    y_test          LR         SVR     RFR
# 0   155.0  156.031216  133.705341  120.99
# 1   167.0  185.700495  146.907788  147.54
# 2   185.0  162.863840  140.965960  169.07
# 3   109.0  162.545441  144.683128  163.45
# 4    65.0   78.518494  118.088552   87.25
# 5    77.0   60.600694  124.899794   88.33
# 6   277.0  175.198247  152.459542  157.88
# 7   244.0  176.770871  153.097167  153.36
# 8   148.0  131.425197  121.363033   99.56
# 9   102.0   88.053772  129.184107  131.48
